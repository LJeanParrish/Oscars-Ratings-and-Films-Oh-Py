# %%
#Import dependencies
import pandas as pd

#Import CSV file
file = 'Resources/the_oscar_award.csv'

# %%
#Create initial dataframe
base_df = pd.read_csv(file, encoding="ISO-8859-1")
base_df = base_df.drop(columns=['year_ceremony', 'ceremony'])

#Print to view
base_df.head()
# Out:
#    year_film category                 name              film  winner
# 0       1927    ACTOR  Richard Barthelmess         The Noose   False
# 1       1927    ACTOR        Emil Jannings  The Last Command    True
# 2       1927  ACTRESS       Louise Dresser   A Ship Comes In   False
# 3       1927  ACTRESS         Janet Gaynor        7th Heaven    True
# 4       1927  ACTRESS       Gloria Swanson    Sadie Thompson   False

# %%
#Find all categories
base_df["category"].unique()
# Out:
# array(['ACTOR', 'ACTRESS', 'ART DIRECTION', 'CINEMATOGRAPHY',
#        'DIRECTING (Comedy Picture)', 'DIRECTING (Dramatic Picture)',
#        'ENGINEERING EFFECTS', 'OUTSTANDING PICTURE',
#        'UNIQUE AND ARTISTIC PICTURE', 'WRITING (Adaptation)',
#        'WRITING (Original Story)', 'WRITING (Title Writing)',
#        'SPECIAL AWARD', 'DIRECTING', 'WRITING', 'OUTSTANDING PRODUCTION',
#        'SOUND RECORDING', 'SHORT SUBJECT (Cartoon)',
#        'SHORT SUBJECT (Comedy)', 'SHORT SUBJECT (Novelty)',
#        'ASSISTANT DIRECTOR', 'FILM EDITING', 'MUSIC (Scoring)',
#        'MUSIC (Song)', 'DANCE DIRECTION', 'WRITING (Screenplay)',
#        'ACTOR IN A SUPPORTING ROLE', 'ACTRESS IN A SUPPORTING ROLE',
#        'SHORT SUBJECT (Color)', 'SHORT SUBJECT (One-reel)',
#        'SHORT SUBJECT (Two-reel)', 'IRVING G. THALBERG MEMORIAL AWARD',
#        'MUSIC (Original Score)', 'CINEMATOGRAPHY (Black-and-White)',
#        'CINEMATOGRAPHY (Color)', 'SPECIAL EFFECTS',
#        'ART DIRECTION (Black-and-White)', 'ART DIRECTION (Color)',
#        'WRITING (Original Screenplay)', 'DOCUMENTARY (Short Subject)',
#        'MUSIC (Music Score of a Dramatic Picture)',
#        'MUSIC (Scoring of a Musical Picture)',
#        'OUTSTANDING MOTION PICTURE', 'DOCUMENTARY',
#        'MUSIC (Music Score of a Dramatic or Comedy Picture)',
#        'WRITING (Original Motion Picture Story)', 'DOCUMENTARY (Feature)',
#        'BEST MOTION PICTURE', 'WRITING (Motion Picture Story)',
#        'COSTUME DESIGN (Black-and-White)', 'COSTUME DESIGN (Color)',
#        'SPECIAL FOREIGN LANGUAGE FILM AWARD',
#        'WRITING (Story and Screenplay)',
#        'HONORARY FOREIGN LANGUAGE FILM AWARD', 'HONORARY AWARD',
#        'FOREIGN LANGUAGE FILM', 'WRITING (Screenplay--Adapted)',
#        'WRITING (Screenplay--Original)',
#        'JEAN HERSHOLT HUMANITARIAN AWARD', 'COSTUME DESIGN',
#        'SHORT SUBJECT (Live Action)',
#        'WRITING (Screenplay--based on material from another medium)',
#        'WRITING (Story and Screenplay--written directly for the screen)',
#        'SOUND', 'MUSIC (Music Score--substantially original)',
#        'MUSIC (Scoring of Music--adaptation or treatment)',
#        'BEST PICTURE', 'SOUND EFFECTS', 'SPECIAL VISUAL EFFECTS',
#        'MUSIC (Original Music Score)',
#        'MUSIC (Original Score--for a motion picture [not a musical])',
#        'MUSIC (Score of a Musical Picture--original or adaptation)',
#        'MUSIC (Song--Original for the Picture)',
#        'WRITING (Story and Screenplay--based on material not previously published or produced)',
#        'MUSIC (Original Song Score)',
#        'WRITING (Story and Screenplay--based on factual material or material not previously published or produced)',
#        'MUSIC (Original Dramatic Score)',
#        'MUSIC (Scoring: Adaptation and Original Song Score)',
#        'SHORT SUBJECT (Animated)',
#        'SPECIAL ACHIEVEMENT AWARD (Visual Effects)',
#        'MUSIC (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)',
#        'SHORT FILM (Animated)', 'SHORT FILM (Live Action)',
#        'WRITING (Screenplay Adapted from Other Material)',
#        'MUSIC (Original Song)',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects)',
#        'ACTOR IN A LEADING ROLE', 'ACTRESS IN A LEADING ROLE',
#        'MUSIC (Original Song Score and Its Adaptation or Adaptation Score)',
#        'WRITING (Screenplay Written Directly for the Screen--based on factual material or on story material not previously published or produced)',
#        'VISUAL EFFECTS', 'SPECIAL ACHIEVEMENT AWARD',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects Editing)',
#        'MUSIC (Adaptation Score)',
#        'WRITING (Screenplay Based on Material from Another Medium)',
#        'WRITING (Screenplay Written Directly for the Screen)',
#        'MUSIC (Original Song Score and Its Adaptation -or- Adaptation Score)',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Editing)',
#        'SHORT FILM (Dramatic Live Action)', 'MAKEUP',
#        'SOUND EFFECTS EDITING',
#        'MUSIC (Original Song Score or Adaptation Score)',
#        'WRITING (Screenplay Based on Material Previously Produced or Published)',
#        'MUSIC (Original Musical or Comedy Score)', 'SOUND EDITING',
#        'ANIMATED FEATURE FILM', 'WRITING (Adapted Screenplay)',
#        'SOUND MIXING', 'MAKEUP AND HAIRSTYLING', 'PRODUCTION DESIGN',
#        'INTERNATIONAL FEATURE FILM'], dtype=object)

# %%
#Combine music score categories 
base_df['category'] = base_df['category'].replace(['MUSIC (Scoring)', 'MUSIC (Music Score of a Dramatic Picture)',
                    'MUSIC (Original Score)', 'MUSIC (Scoring of a Musical Picture)', 
                     'MUSIC (Music Score of a Dramatic or Comedy Picture)', 'MUSIC (Music Score--substantially original)',
                    'MUSIC (Original Music Score)',
                   'MUSIC (Original Score--for a motion picture [not a musical])',
                    'MUSIC (Score of a Musical Picture--original or adaptation)', 'MUSIC (Original Song Score)',
                    'MUSIC (Original Dramatic Score)', 'MUSIC (Scoring: Adaptation and Original Song Score)',
                    'MUSIC (Original Song Score and Its Adaptation or Adaptation Score)',
                    'MUSIC (Original Song Score and Its Adaptation -or- Adaptation Score)',
                    'MUSIC (Original Musical or Comedy Score)', 'MUSIC (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)',
                    'MUSIC (Original Song Score or Adaptation Score)', 'MUSIC (Adaptation Score)', 
                    'MUSIC (Scoring of Music--adaptation or treatment)'], 'MUSIC SCORE')

# %%
#Combine writing categories
base_df['category'] = base_df['category'].replace(['WRITING (Adaptation)', 'WRITING (Original Story)',
                    'WRITING (Screenplay)', 'WRITING (Original Screenplay)', 'WRITING (Original Motion Picture Story)',
                    'WRITING (Story and Screenplay)', 'WRITING (Screenplay--Original)', 
                    'WRITING (Story and Screenplay--based on material not previously published or produced)',
                     'WRITING (Story and Screenplay--written directly for the screen)', 
                    'WRITING (Story and Screenplay--based on material not previously published or produced)',
       'WRITING (Story and Screenplay--based on factual material or material not previously published or produced)',
                    'WRITING (Screenplay Adapted from Other Material)',
                    'WRITING (Screenplay Written Directly for the Screen--based on factual material or on story material not previously published or produced)',
                'WRITING (Screenplay Based on Material from Another Medium)', 'WRITING (Screenplay Written Directly for the Screen)',
                    'WRITING (Screenplay Based on Material Previously Produced or Published)', 'WRITING (Screenplay--based on material from another medium)',
                    'WRITING (Motion Picture Story)', 'WRITING (Adapted Screenplay)', 'WRITING (Screenplay--Adapted)'], 'WRITING')

# %%
#Combine Short Subject categories
base_df["category"] = base_df['category'].replace(['SHORT SUBJECT (Cartoon)', 'SHORT SUBJECT (Comedy)',
       'SHORT SUBJECT (Novelty)', 'SHORT SUBJECT (Color)', 'SHORT SUBJECT (One-reel)','SHORT SUBJECT (Two-reel)',
        'SHORT SUBJECT (Live Action)', 'SHORT SUBJECT (Animated)'] , 'SHORT SUBJECT')

# %%
#Combine scientific/technical award categories
base_df['category'] = base_df['category'].replace(['SCIENTIFIC OR TECHNICAL AWARD (Class I)',
       'SCIENTIFIC OR TECHNICAL AWARD (Class II)', 'SCIENTIFIC OR TECHNICAL AWARD (Class III)',
        'SCIENTIFIC OR TECHNICAL AWARD (Academy Award of Merit)',
       'SCIENTIFIC OR TECHNICAL AWARD (Scientific and Engineering Award)',
       'SCIENTIFIC OR TECHNICAL AWARD (Technical Achievement Award)',
        'SCIENTIFIC AND TECHNICAL AWARD (Special Award)', 'SCIENTIFIC AND TECHNICAL AWARD (Academy Award of Merit)',
       'SCIENTIFIC AND TECHNICAL AWARD (Scientific and Engineering Award)',
       'SCIENTIFIC AND TECHNICAL AWARD (Technical Achievement Award)'], 'SCIENTIFIC/TECHNICAL AWARD')

# %%
#Combine original song categories
base_df['category'] = base_df['category'].replace(['MUSIC (Song)', 'MUSIC (Song--Original for the Picture)',
                                'MUSIC (Original Song)'], 'ORIGINAL SONG')

# %%
#Combine costume design categories
base_df['category'] = base_df['category'].replace(['COSTUME DESIGN (Black-and-White)', 'COSTUME DESIGN (Color)'], 'COSTUME DESIGN')

# %%
#Combine short film
base_df['category'] = base_df['category'].replace(['SHORT FILM (Animated)', 'SHORT FILM (Live Action)', 'SHORT FILM (Dramatic Live Action)'], 
                                'SHORT FILM')

# %%
#Combine directing category
base_df['category'] = base_df['category'].replace(['DIRECTING (Comedy Picture)', 'DIRECTING (Dramatic Picture)'], 'DIRECTING')

# %%
#Combine documentary category
base_df['category'] = base_df['category'].replace(['DOCUMENTARY (Short Subject)', 'DOCUMENTARY (Feature)'], 'DOCUMENTARY')

# %%
#Combine cinematography category
base_df['category'] = base_df['category'].replace(['CINEMATOGRAPHY (Black-and-White)', 'CINEMATOGRAPHY (Color)'], 'CINEMATOGRAPHY')

# %%
#Combine art direction category
base_df['category'] = base_df['category'].replace(['ART DIRECTION (Black-and-White)', 'ART DIRECTION (Color)'], 'ART DIRECTION')

# %%
base_df["category"].unique()
# Out:
# array(['ACTOR', 'ACTRESS', 'ART DIRECTION', 'CINEMATOGRAPHY', 'DIRECTING',
#        'ENGINEERING EFFECTS', 'OUTSTANDING PICTURE',
#        'UNIQUE AND ARTISTIC PICTURE', 'WRITING',
#        'WRITING (Title Writing)', 'SPECIAL AWARD',
#        'OUTSTANDING PRODUCTION', 'SOUND RECORDING', 'SHORT SUBJECT',
#        'ASSISTANT DIRECTOR', 'FILM EDITING', 'MUSIC SCORE',
#        'ORIGINAL SONG', 'DANCE DIRECTION', 'ACTOR IN A SUPPORTING ROLE',
#        'ACTRESS IN A SUPPORTING ROLE',
#        'IRVING G. THALBERG MEMORIAL AWARD', 'SPECIAL EFFECTS',
#        'DOCUMENTARY', 'OUTSTANDING MOTION PICTURE', 'BEST MOTION PICTURE',
#        'COSTUME DESIGN', 'SPECIAL FOREIGN LANGUAGE FILM AWARD',
#        'HONORARY FOREIGN LANGUAGE FILM AWARD', 'HONORARY AWARD',
#        'FOREIGN LANGUAGE FILM', 'JEAN HERSHOLT HUMANITARIAN AWARD',
#        'SOUND', 'BEST PICTURE', 'SOUND EFFECTS', 'SPECIAL VISUAL EFFECTS',
#        'SPECIAL ACHIEVEMENT AWARD (Visual Effects)', 'SHORT FILM',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects)',
#        'ACTOR IN A LEADING ROLE', 'ACTRESS IN A LEADING ROLE',
#        'VISUAL EFFECTS', 'SPECIAL ACHIEVEMENT AWARD',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Effects Editing)',
#        'SPECIAL ACHIEVEMENT AWARD (Sound Editing)', 'MAKEUP',
#        'SOUND EFFECTS EDITING', 'SOUND EDITING', 'ANIMATED FEATURE FILM',
#        'SOUND MIXING', 'MAKEUP AND HAIRSTYLING', 'PRODUCTION DESIGN',
#        'INTERNATIONAL FEATURE FILM'], dtype=object)

# %%
#Export dataframe to csv
base_df.to_csv('Resources/cleaned_data.csv')

# %%
#Create winning actor dataframe
winner_db = base_df.loc[base_df['winner'] == True, :]
actors = winner_db.loc[winner_db['category'] == 'ACTOR', :]
actors = actors.reset_index(drop=True)
actors.head()
# Out:
#    year_film category              name              film  winner
# 0       1927    ACTOR     Emil Jannings  The Last Command    True
# 1       1928    ACTOR     Warner Baxter    In Old Arizona    True
# 2       1929    ACTOR     George Arliss          Disraeli    True
# 3       1930    ACTOR  Lionel Barrymore       A Free Soul    True
# 4       1931    ACTOR     Wallace Beery         The Champ    True

# %%
#Create winning actress dataframe
actress = winner_db.loc[winner_db['category'] == 'ACTRESS', :]
actress = actress.reset_index(drop=True)
actress.head()
# Out:
#    year_film category            name                        film  winner
# 0       1927  ACTRESS    Janet Gaynor                  7th Heaven    True
# 1       1928  ACTRESS   Mary Pickford                    Coquette    True
# 2       1929  ACTRESS   Norma Shearer                The Divorcee    True
# 3       1930  ACTRESS  Marie Dressler                Min and Bill    True
# 4       1931  ACTRESS     Helen Hayes  The Sin of Madelon Claudet    True

# %%
#Create winning directing dataframe
directing = winner_db.loc[winner_db['category'] == 'DIRECTING', :]
directing = directing.reset_index(drop=True)
directing.head()
# Out:
#    year_film   category             name                            film  \
# 0       1927  DIRECTING  Lewis Milestone             Two Arabian Knights
# 1       1927  DIRECTING    Frank Borzage                      7th Heaven
# 2       1928  DIRECTING      Frank Lloyd                 The Divine Lady
# 3       1929  DIRECTING  Lewis Milestone  All Quiet on the Western Front
# 4       1930  DIRECTING    Norman Taurog                          Skippy
#
#    winner
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
#Create winning music score dataframe
music_score = winner_db.loc[winner_db['category'] == 'MUSIC SCORE', :]
music_score = music_score.reset_index(drop=True)
music_score.head()
# Out:
#    year_film     category                                               name  \
# 0       1934  MUSIC SCORE  Columbia Studio Music Department, Louis Silver...
# 1       1935  MUSIC SCORE  RKO Radio Studio Music Department, Max Steiner...
# 2       1936  MUSIC SCORE  Warner Bros. Studio Music Department, Leo Forb...
# 3       1937  MUSIC SCORE  Universal Studio Music Department, Charles Pre...
# 4       1938  MUSIC SCORE                            Erich Wolfgang Korngold
#
#                            film  winner
# 0             One Night of Love    True
# 1                  The Informer    True
# 2               Anthony Adverse    True
# 3    One Hundred Men and a Girl    True
# 4  The Adventures of Robin Hood    True

# %%
#Create winning original song dataframe
original_song = winner_db.loc[winner_db['category'] == 'ORIGINAL SONG', :]
original_song = original_song.reset_index(drop=True)
original_song
# Out:
#     year_film       category  \
# 0        1934  ORIGINAL SONG
# 1        1935  ORIGINAL SONG
# 2        1936  ORIGINAL SONG
# 3        1937  ORIGINAL SONG
# 4        1938  ORIGINAL SONG
# ..        ...            ...
# 81       2015  ORIGINAL SONG
# 82       2016  ORIGINAL SONG
# 83       2017  ORIGINAL SONG
# 84       2018  ORIGINAL SONG
# 85       2019  ORIGINAL SONG
#
#                                                  name  \
# 0        Music by Con Conrad; Lyrics by Herb Magidson
# 1           Music by Harry Warren; Lyrics by Al Dubin
# 2      Music by Jerome Kern; Lyrics by Dorothy Fields
# 3                     Music and Lyrics by Harry Owens
# 4         Music by Ralph Rainger; Lyrics by Leo Robin
# ..                                                ...
# 81       Music and Lyric by Jimmy Napes and Sam Smith
# 82  Music by Justin Hurwitz; Lyric by Benj Pasek a...
# 83  Music and Lyric by Kristen Anderson-Lopez and ...
# 84  Music and Lyric by Lady Gaga, Mark Ronson, Ant...
# 85        Music by Elton John; Lyric by Bernie Taupin
#
#                          film  winner
# 0            The Gay Divorcee    True
# 1        Gold Diggers of 1935    True
# 2                  Swing Time    True
# 3             Waikiki Wedding    True
# 4   The Big Broadcast of 1938    True
# ..                        ...     ...
# 81                    Spectre    True
# 82                 La La Land    True
# 83                       Coco    True
# 84             A Star Is Born    True
# 85                  Rocketman    True
#
# [86 rows x 5 columns]

# %%
#Create winning writing dataframe
writing = winner_db.loc[winner_db['category'] == 'WRITING', :]
writing = writing.reset_index(drop=True)
writing.head()
# Out:
#    year_film category              name           film  winner
# 0       1927  WRITING   Benjamin Glazer     7th Heaven    True
# 1       1927  WRITING         Ben Hecht     Underworld    True
# 2       1928  WRITING        Hans Kraly    The Patriot    True
# 3       1929  WRITING    Frances Marion  The Big House    True
# 4       1930  WRITING  Howard Estabrook       Cimarron    True

# %%
#Create winning costume design dataframe
costume_design = winner_db.loc[winner_db['category'] == 'COSTUME DESIGN', :]
costume_design = costume_design.reset_index(drop=True)
costume_design.head()
# Out:
#    year_film        category                                  name  \
# 0       1948  COSTUME DESIGN                        Roger K. Furse
# 1       1948  COSTUME DESIGN             Dorothy Jeakins, Karinska
# 2       1949  COSTUME DESIGN               Edith Head, Gile Steele
# 3       1949  COSTUME DESIGN  Leah Rhodes, Travilla, Marjorie Best
# 4       1950  COSTUME DESIGN           Edith Head, Charles LeMaire
#
#                          film  winner
# 0                      Hamlet    True
# 1                 Joan of Arc    True
# 2                 The Heiress    True
# 3  The Adventures of Don Juan    True
# 4               All about Eve    True

# %%
#Create winning short film dataframe
short_film = winner_db.loc[winner_db['category'] == 'SHORT FILM', :]
short_film = short_film.reset_index(drop=True)
short_film.head()
# Out:
#    year_film    category                                       name  \
# 0       1974  SHORT FILM    Will Vinton and Bob Gardiner, Producers
# 1       1974  SHORT FILM  Paul Claudon and Edmond Sechan, Producers
# 2       1975  SHORT FILM                      Bob Godfrey, Producer
# 3       1975  SHORT FILM                     Bert Salzman, Producer
# 4       1976  SHORT FILM                    Suzanne Baker, Producer
#
#                      film  winner
# 0          Closed Mondays    True
# 1  One-Eyed Men Are Kings    True
# 2                   Great    True
# 3       Angel and Big Joe    True
# 4                 Leisure    True

# %%
#Create winning actor directing
directing = winner_db.loc[winner_db['category'] == 'DIRECTING', :]
directing = directing.reset_index(drop=True)
directing.head()
# Out:
#    year_film   category             name                            film  \
# 0       1927  DIRECTING  Lewis Milestone             Two Arabian Knights
# 1       1927  DIRECTING    Frank Borzage                      7th Heaven
# 2       1928  DIRECTING      Frank Lloyd                 The Divine Lady
# 3       1929  DIRECTING  Lewis Milestone  All Quiet on the Western Front
# 4       1930  DIRECTING    Norman Taurog                          Skippy
#
#    winner
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
#Create winning documentary dataframe
documentary = winner_db.loc[winner_db['category'] == 'DOCUMENTARY', :]
documentary = documentary.reset_index(drop=True)
documentary.head()
# Out:
#    year_film     category                                  name  \
# 0       1941  DOCUMENTARY         National Film Board of Canada
# 1       1942  DOCUMENTARY                    United States Navy
# 2       1942  DOCUMENTARY  Australian News & Information Bureau
# 3       1942  DOCUMENTARY                               Artkino
# 4       1942  DOCUMENTARY   United States Army Special Services
#
#                    film  winner
# 0    Churchill's Island    True
# 1  The Battle of Midway    True
# 2    Kokoda Front Line!    True
# 3   Moscow Strikes Back    True
# 4        Prelude to War    True

# %%
#Create winning actor cinematography
cinematography = winner_db.loc[winner_db['category'] == 'CINEMATOGRAPHY', :]
cinematography = cinematography.reset_index(drop=True)
cinematography.head()
# Out:
#    year_film        category                                    name  \
# 0       1927  CINEMATOGRAPHY                          Charles Rosher
# 1       1927  CINEMATOGRAPHY                             Karl Struss
# 2       1928  CINEMATOGRAPHY                          Clyde De Vinna
# 3       1929  CINEMATOGRAPHY  Joseph T. Rucker, Willard Van Der Veer
# 4       1930  CINEMATOGRAPHY                            Floyd Crosby
#
#                               film  winner
# 0                          Sunrise    True
# 1                          Sunrise    True
# 2  White Shadows in the South Seas    True
# 3      With Byrd at the South Pole    True
# 4                             Tabu    True

# %%
#Create winning actor art direction
art_direction = winner_db.loc[winner_db['category'] == 'ART DIRECTION', :]
art_direction = art_direction.reset_index(drop=True)
art_direction.head()
# Out:
#    year_film       category                     name  \
# 0       1927  ART DIRECTION  William Cameron Menzies
# 1       1928  ART DIRECTION           Cedric Gibbons
# 2       1929  ART DIRECTION             Herman Rosse
# 3       1930  ART DIRECTION                 Max RÃ©e
# 4       1931  ART DIRECTION             Gordon Wiles
#
#                          film  winner
# 0                   The Dove;    True
# 1  The Bridge of San Luis Rey    True
# 2                King of Jazz    True
# 3                    Cimarron    True
# 4               Transatlantic    True

# %%
best_picture = winner_db.loc[winner_db['category'] == 'BEST PICTURE', :]
best_picture = best_picture.reset_index(drop=True)
best_picture
# Out:
#     year_film      category  \
# 0        1962  BEST PICTURE
# 1        1963  BEST PICTURE
# 2        1964  BEST PICTURE
# 3        1965  BEST PICTURE
# 4        1966  BEST PICTURE
# 5        1967  BEST PICTURE
# 6        1968  BEST PICTURE
# 7        1969  BEST PICTURE
# 8        1970  BEST PICTURE
# 9        1971  BEST PICTURE
# 10       1972  BEST PICTURE
# 11       1973  BEST PICTURE
# 12       1974  BEST PICTURE
# 13       1975  BEST PICTURE
# 14       1976  BEST PICTURE
# 15       1977  BEST PICTURE
# 16       1978  BEST PICTURE
# 17       1979  BEST PICTURE
# 18       1980  BEST PICTURE
# 19       1981  BEST PICTURE
# 20       1982  BEST PICTURE
# 21       1983  BEST PICTURE
# 22       1984  BEST PICTURE
# 23       1985  BEST PICTURE
# 24       1986  BEST PICTURE
# 25       1987  BEST PICTURE
# 26       1988  BEST PICTURE
# 27       1989  BEST PICTURE
# 28       1990  BEST PICTURE
# 29       1991  BEST PICTURE
# 30       1992  BEST PICTURE
# 31       1993  BEST PICTURE
# 32       1994  BEST PICTURE
# 33       1995  BEST PICTURE
# 34       1996  BEST PICTURE
# 35       1997  BEST PICTURE
# 36       1998  BEST PICTURE
# 37       1999  BEST PICTURE
# 38       2000  BEST PICTURE
# 39       2001  BEST PICTURE
# 40       2002  BEST PICTURE
# 41       2003  BEST PICTURE
# 42       2004  BEST PICTURE
# 43       2005  BEST PICTURE
# 44       2006  BEST PICTURE
# 45       2007  BEST PICTURE
# 46       2008  BEST PICTURE
# 47       2009  BEST PICTURE
# 48       2010  BEST PICTURE
# 49       2011  BEST PICTURE
# 50       2012  BEST PICTURE
# 51       2013  BEST PICTURE
# 52       2014  BEST PICTURE
# 53       2015  BEST PICTURE
# 54       2016  BEST PICTURE
# 55       2017  BEST PICTURE
# 56       2018  BEST PICTURE
# 57       2019  BEST PICTURE
#
#                                                  name  \
# 0                               Sam Spiegel, Producer
# 1                           Tony Richardson, Producer
# 2                            Jack L. Warner, Producer
# 3                               Robert Wise, Producer
# 4                            Fred Zinnemann, Producer
# 5                            Walter Mirisch, Producer
# 6                                John Woolf, Producer
# 7                            Jerome Hellman, Producer
# 8                            Frank McCarthy, Producer
# 9                           Philip D'Antoni, Producer
# 10                          Albert S. Ruddy, Producer
# 11  Tony Bill, Michael Phillips and Julia Phillips...
# 12  Francis Ford Coppola, Producer;  Gray Frederic...
# 13         Saul Zaentz and Michael Douglas, Producers
# 14       Irwin Winkler and Robert Chartoff, Producers
# 15                         Charles H. Joffe, Producer
# 16  Barry Spikings, Michael Deeley, Michael Cimino...
# 17                         Stanley R. Jaffe, Producer
# 18                        Ronald L. Schwary, Producer
# 19                            David Puttnam, Producer
# 20                     Richard Attenborough, Producer
# 21                          James L. Brooks, Producer
# 22                              Saul Zaentz, Producer
# 23                           Sydney Pollack, Producer
# 24                          Arnold Kopelson, Producer
# 25                            Jeremy Thomas, Producer
# 26                             Mark Johnson, Producer
# 27  Richard D. Zanuck and Lili Fini Zanuck, Producers
# 28            Jim Wilson and Kevin Costner, Producers
# 29  Edward Saxon, Kenneth Utt and Ron Bozman, Prod...
# 30                           Clint Eastwood, Producer
# 31  Steven Spielberg, Gerald R. Molen and Branko L...
# 32  Wendy Finerman, Steve Tisch and Steve Starkey,...
# 33  Mel Gibson, Alan Ladd, Jr. and Bruce Davey, Pr...
# 34                              Saul Zaentz, Producer
# 35            James Cameron and Jon Landau, Producers
# 36  David Parfitt, Donna Gigliotti, Harvey Weinste...
# 37               Bruce Cohen and Dan Jinks, Producers
# 38  Douglas Wick, David Franzoni and Branko Lustig...
# 39             Brian Grazer and Ron Howard, Producers
# 40                          Martin Richards, Producer
# 41  Barrie M. Osborne, Peter Jackson and Fran Wals...
# 42  Clint Eastwood, Albert S. Ruddy and Tom Rosenb...
# 43          Paul Haggis and Cathy Schulman, Producers
# 44                              Graham King, Producer
# 45   Scott Rudin, Ethan Coen and Joel Coen, Producers
# 46                         Christian Colson, Producer
# 47  Kathryn Bigelow, Mark Boal, Nicolas Chartier a...
# 48  Iain Canning, Emile Sherman and Gareth Unwin, ...
# 49                          Thomas Langmann, Producer
# 50  Grant Heslov, Ben Affleck and George Clooney, ...
# 51  Brad Pitt, Dede Gardner, Jeremy Kleiner, Steve...
# 52  Alejandro G. IÃ±Ã¡rritu, John Lesher and James...
# 53  Michael Sugar, Steve Golin, Nicole Rocklin and...
# 54  Adele Romanski, Dede Gardner and Jeremy Kleine...
# 55    Guillermo del Toro and J. Miles Dale, Producers
# 56  Jim Burke, Charles B. Wessler, Brian Currie, P...
# 57            Kwak Sin Ae and Bong Joon Ho, Producers
#
#                                                film  winner
# 0                                Lawrence of Arabia    True
# 1                                         Tom Jones    True
# 2                                      My Fair Lady    True
# 3                                The Sound of Music    True
# 4                             A Man for All Seasons    True
# 5                          In the Heat of the Night    True
# 6                                           Oliver!    True
# 7                                   Midnight Cowboy    True
# 8                                            Patton    True
# 9                             The French Connection    True
# 10                                    The Godfather    True
# 11                                        The Sting    True
# 12                            The Godfather Part II    True
# 13                  One Flew over the Cuckoo's Nest    True
# 14                                            Rocky    True
# 15                                       Annie Hall    True
# 16                                  The Deer Hunter    True
# 17                                Kramer vs. Kramer    True
# 18                                  Ordinary People    True
# 19                                 Chariots of Fire    True
# 20                                           Gandhi    True
# 21                              Terms of Endearment    True
# 22                                          Amadeus    True
# 23                                    Out of Africa    True
# 24                                          Platoon    True
# 25                                 The Last Emperor    True
# 26                                         Rain Man    True
# 27                               Driving Miss Daisy    True
# 28                               Dances With Wolves    True
# 29                         The Silence of the Lambs    True
# 30                                       Unforgiven    True
# 31                                 Schindler's List    True
# 32                                     Forrest Gump    True
# 33                                       Braveheart    True
# 34                              The English Patient    True
# 35                                          Titanic    True
# 36                              Shakespeare in Love    True
# 37                                  American Beauty    True
# 38                                        Gladiator    True
# 39                                 A Beautiful Mind    True
# 40                                          Chicago    True
# 41    The Lord of the Rings: The Return of the King    True
# 42                              Million Dollar Baby    True
# 43                                            Crash    True
# 44                                     The Departed    True
# 45                           No Country for Old Men    True
# 46                              Slumdog Millionaire    True
# 47                                  The Hurt Locker    True
# 48                                The King's Speech    True
# 49                                       The Artist    True
# 50                                             Argo    True
# 51                                 12 Years a Slave    True
# 52  Birdman or (The Unexpected Virtue of Ignorance)    True
# 53                                        Spotlight    True
# 54                                        Moonlight    True
# 55                               The Shape of Water    True
# 56                                       Green Book    True
# 57                                         Parasite    True
